# %%
from unittest.mock import inplace

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # visualization
import matplotlib.pyplot as plt
import re
# %matplotlib inline


data = pd.DataFrame( pd.read_excel('./breast-cancer.xls') )  # Data Import from local/ Drive file



data.at[1 , 'age'] = 10
data.sample(len(data))
# Out:
#        age menopause           tumor-size            inv-nodes node-caps  \
# 157  30-39   premeno                20-24  2019-05-03 00:00:00       yes
# 199  60-69      ge40                20-24                  0-2        no
# 87   30-39   premeno                25-29  2019-08-06 00:00:00       yes
# 214  40-49   premeno                20-24                  0-2        no
# 86   40-49   premeno                40-44                  0-2        no
# ..     ...       ...                  ...                  ...       ...
# 124  30-39   premeno  2014-10-01 00:00:00                  0-2        no
# 130  40-49   premeno                30-34                  0-2        no
# 73   50-59      ge40                30-34  2019-08-06 00:00:00       yes
# 260  70-79      ge40                20-24                  0-2        no
# 120  40-49   premeno                30-34                  0-2       yes
#
#      deg-malig breast breast-quad irradiat                 Class
# 157          2   left    left_low       no     recurrence-events
# 199          3  right    left_low       no     recurrence-events
# 87           2  right     left_up      yes  no-recurrence-events
# 214          2  right     left_up       no  no-recurrence-events
# 86           1  right     left_up       no  no-recurrence-events
# ..         ...    ...         ...      ...                   ...
# 124          2   left   right_low       no  no-recurrence-events
# 130          2   left   right_low       no  no-recurrence-events
# 73           3   left   right_low       no     recurrence-events
# 260          3   left     left_up       no  no-recurrence-events
# 120          3  right    right_up       no     recurrence-events
#
# [286 rows x 10 columns]
